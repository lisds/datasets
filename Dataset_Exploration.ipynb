# %%
import pandas as pd

df = pd.read_csv("data/ckd_clean.csv")

df
# Out:
#       Age  Blood Pressure  Specific Gravity  Albumin  Sugar Red Blood Cells  \
# 0    48.0            70.0             1.005      4.0    0.0          normal
# 1    53.0            90.0             1.020      2.0    0.0        abnormal
# 2    63.0            70.0             1.010      3.0    0.0        abnormal
# 3    68.0            80.0             1.010      3.0    2.0          normal
# 4    61.0            80.0             1.015      2.0    0.0        abnormal
# ..    ...             ...               ...      ...    ...             ...
# 153  55.0            80.0             1.020      0.0    0.0          normal
# 154  42.0            70.0             1.025      0.0    0.0          normal
# 155  12.0            80.0             1.020      0.0    0.0          normal
# 156  17.0            60.0             1.025      0.0    0.0          normal
# 157  58.0            80.0             1.025      0.0    0.0          normal
#
# ...
